# %%
import numpy as np

# %%
betas_correct = np.loadtxt("experiments/2d/mgpcg/betas.dat")
betas_incorrect = np.loadtxt("experiments/2d/mgpcg_wrong/betas.dat")

# %%
# plot the betas
import matplotlib.pyplot as plt
plt.plot(betas_correct, label="correct")
plt.plot(betas_incorrect, label="incorrect")
plt.legend()
plt.yscale("log")
plt.show()
