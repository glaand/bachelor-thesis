# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from train_lid_driven_cavity_glatzl import custom_loss

# %%
ml_residuals_without = np.loadtxt("../experiments/2d/ml/residuals_without_pressure_solver.dat")
mgpcg_residuals_without = np.loadtxt("../experiments/2d/mgpcg/residuals_without_pressure_solver.dat")
cg_residuals_without = np.loadtxt("../experiments/2d/conjugate_gradient/residuals_without_pressure_solver.dat")

# Plot the residuals

# Set title, explain what plot ist
plt.figure(figsize=(16, 6))
plt.title("Residuals after each time step")
plt.plot(ml_residuals_without, label="AI-Assisted MGPCG")
plt.plot(mgpcg_residuals_without, label="MGPCG", alpha=0.7)
plt.plot(cg_residuals_without, label="CG", alpha=0.7)

plt.yscale("log")
plt.xlabel("Iterations")
plt.ylabel("Residual")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 ml_residuals_without = np.loadtxt("../experiments/2d/ml/residuals_without_pressure_solver.dat")
# ----> 2 mgpcg_residuals_without = np.loadtxt("../experiments/2d/mgpcg/residuals_without_pressure_solver.dat")
#       3 cg_residuals_without = np.loadtxt("../experiments/2d/conjugate_gradient/residuals_without_pressure_solver.dat")
#       5 # Plot the residuals
#       6
#       7 # Set title, explain what plot ist
#
# File ~/miniconda3/envs/bachelor-thesis/lib/python3.11/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File ~/miniconda3/envs/bachelor-thesis/lib/python3.11/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/miniconda3/envs/bachelor-thesis/lib/python3.11/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniconda3/envs/bachelor-thesis/lib/python3.11/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: ../experiments/2d/mgpcg/residuals_without_pressure_solver.dat not found.

# %%
ml_residuals_with = np.loadtxt("../experiments/2d/ml/residuals_with_pressure_solver.dat")
mgpcg_residuals_with = np.loadtxt("../experiments/2d/mgpcg/residuals_with_pressure_solver.dat")

# Plot the residuals

# Set title, explain what plot ist
plt.figure(figsize=(16, 6))
plt.title("Residuals after each time step")
plt.plot(ml_residuals_with, label="AI-Assisted MGPCG")
plt.plot(mgpcg_residuals_with, label="MGPCG", alpha=0.7)

plt.yscale("log")
plt.xscale("log")
plt.xlabel("Iterations")
plt.ylabel("Residual")
plt.legend()
plt.show()

# %%
num_file = 0
input_error = np.loadtxt(f"ML_data/input_error_{num_file}.dat")
ideal_error = np.loadtxt(f"ML_data/ideal_error_{num_file}.dat")
input_error = torch.tensor(input_error).to('cuda')

# Load the torchscript model
model = torch.jit.load("model_glatzl.pt")
model.eval()

# Calculate e_data with the model
with torch.no_grad():
    pred_error = model(input_error.float().unsqueeze(0).unsqueeze(0))
    # Plot pred_error as heatmap
    pred_error = pred_error.to('cpu').squeeze(0).squeeze(0)
    pred_error = pred_error
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Plot e_data from the model
    im1 = axs[0].imshow(pred_error, cmap='hot', interpolation='nearest')
    axs[0].set_title('Predicted e-Vector')
    axs[0].invert_yaxis()
    fig.colorbar(im1, ax=axs[0])

    # Calculate loss
    grid_size_x, grid_size_y = pred_error.shape
    pred_error = pred_error.unsqueeze(0).unsqueeze(0).to('cpu')
    ideal_error = torch.tensor(ideal_error).unsqueeze(0).unsqueeze(0).to('cpu')

# Load e_data from file
e_data = np.loadtxt(f"ML_data/ideal_error_{num_file}.dat")
e_data = torch.tensor(e_data).to('cpu')
# Plot e_data from file as heatmap
im2 = axs[1].imshow(e_data-input_error.to('cpu'), cmap='hot', interpolation='nearest')
axs[1].set_title('True e-Vector')
axs[1].invert_yaxis()
fig.colorbar(im2, ax=axs[1])

plt.show()

# %%
# get size of the model
model_size = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Model size: {model_size}")
# Out:
# Model size: 291058

# %%
e_data = np.loadtxt("ML_data/res_5000.dat")
# plot e_data as heatmap
plt.imshow(e_data, cmap='hot', interpolation='nearest')
# invert the y-axis
plt.gca().invert_yaxis()
plt.colorbar()
plt.show()
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'bachelor-thesis (Python 3.11.5)' due to a connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Ghia et al. (1982) - Re = 100
reference_ux_RE_100 = {
    128: 1.00000,
    125: 0.84123,
    124: 0.78871,
    123: 0.73722,
    122: 0.68717,
    109: 0.23151,
    94: 0.00332,
    79: -0.13641,
    64: -0.20581,
    58: -0.21090,
    36: -0.15662,
    22: -0.10150,
    13: -0.06434,
    9: -0.04775,
    8: -0.04192,
    7: -0.03717,
    0: 0.00000
}

# Ghia et al. (1982) - Re = 100
reference_uy_RE_100 = {
    128: 0.00000,
    124: -0.05906,
    123: -0.07391,
    122: -0.08864,
    121: -0.10313,
    116: -0.16914,
    110: -0.22445,
    103: -0.24533,
    64: 0.05454,
    30: 0.17527,
    29: 0.17507,
    20: 0.16077,
    12: 0.12317,
    10: 0.10890,
    9: 0.10091,
    8: 0.09233,
    0: 0.00000
}

u = np.loadtxt("../experiments/2d/mgpcg/u.dat")
v = np.loadtxt("../experiments/2d/mgpcg/v.dat")

u = u[1:-1, 1:-1]
v = v[1:-1, 1:-1]

scale_factor = 4
u = np.kron(u, np.ones((scale_factor, scale_factor)))
v = np.kron(v, np.ones((scale_factor, scale_factor)))

# plot u
u = u[:, int(u.shape[1]/2)]
v = v[int(v.shape[0]/2), :]

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 5))  # Create a figure with 2 subplots side by side

# Plot u and its reference
axes[0].plot(u, label="MGPCG ML")
axes[0].scatter(reference_ux_RE_100.keys(), reference_ux_RE_100.values(), label="Ghia et al. (1982)")
axes[0].set_title("Velocity Component u")
axes[0].legend()

# Plot v and its reference
axes[1].plot(v, label="MGPCG ML")
# plot v_mid as scatter plot
axes[1].scatter(reference_uy_RE_100.keys(), reference_uy_RE_100.values(), label="Ghia et al. (1982)")
axes[1].set_title("Velocity Component v")
axes[1].legend()

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'bachelor-thesis (Python 3.11.5)' due to a connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
